# %% [markdown]
# ## Configuración e importación de módulos
#
# Añadimos la carpeta 'src' al path para poder importar tus módulos

# %%
import sys
import pandas as pd

sys.path.append('./src')
import modules.phase1_2_universe as m1
import modules.phase3_preprocessing as m3
import modules.phase4_transforming as m4
import modules.phase5_supervised as m5
import modules.phase6_unsupervised as m6

RUTA_CSV      = './ENIGH_INEGI/viviendas.csv'
CVE_ESTADO    = '15'
NOMBRE_ESTADO = 'Estado de Mexico'
ATRIBUTOS     = ['num_cuarto', 'tam_loc', 'calent_sol', 'p_fractura', 'regadera', 'tenencia']

# %% [markdown]
# ## FASE 1 Y 2: UNIVERSO DE DATOS Y SELECCIÓN
#
# Ejecuta la limpieza inicial y muestra las matrices de correlación, además de filtrar los datos por estado y desplegar las gráficas de calor configuradas con Seaborn.

# %%
print(f"Iniciando extracción para: {NOMBRE_ESTADO}")

df_estado = m1.ejecutar(RUTA_CSV, CVE_ESTADO, NOMBRE_ESTADO, ATRIBUTOS)

display(df_estado.head())
# Out:
# Iniciando extracción para: Estado de Mexico
# Registros totales: 90,324
# Columnas        : 82
#
# Registros en Estado de Mexico: 3,524
#
# Primeras filas:
#          folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 41814  1505018801        1          1          10         2         13
# 41815  1505018803        1          8          10         3         28
# 41816  1505018804        1          8          10         3         13
#
#        antigua_ne  cocina  cocina_dor  cuart_dorm  ...  tot_muj  tot_hog  \
# 41814         NaN       1         2.0           2  ...        2        1
# 41815         NaN       1         2.0           2  ...        1        1
# 41816         NaN       1         2.0           2  ...        1        1
#
#        ubica_geo  tam_loc  est_socio  est_dis   upm  factor  procaptar  \
# 41814      15002        3          2      287  5018    4340          0
# 41815      15002        3          2      287  5018    4340          0
# 41816      15002        3          2      287  5018    4340          0
#
#        cve_estado
# 41814          15
# 41815          15
# 41816          15
#
# [3 rows x 83 columns]
#
# Tipos de datos:
# folioviv       int64
# tipo_viv      object
# mat_pared      int64
# mat_techos     int64
# mat_pisos     object
#                ...
# est_dis        int64
# upm            int64
# factor         int64
# procaptar      int64
# cve_estado    object
# Length: 83, dtype: object
#
# Estadísticas descriptivas:
#            folioviv    mat_pared   mat_techos  antigua_ne       cocina  \
# count  3.524000e+03  3524.000000  3524.000000       338.0  3524.000000
# mean   1.538975e+09     7.887911     9.191260         1.0     1.053916
# std    2.474549e+07     0.576463     2.111502         0.0     0.225884
# min    1.505019e+09     1.000000     1.000000         1.0     1.000000
# 25%    1.515168e+09     8.000000    10.000000         1.0     1.000000
# 50%    1.535328e+09     8.000000    10.000000         1.0     1.000000
# 75%    1.565401e+09     8.000000    10.000000         1.0     1.000000
# max    1.565441e+09     8.000000    10.000000         1.0     2.000000
#
#         cocina_dor   cuart_dorm   num_cuarto    lugar_coc     agua_ent  ...  \
# count  3334.000000  3524.000000  3524.000000  3524.000000  3524.000000  ...
# mean      1.946611     2.139898     3.907208     1.239784     1.372588  ...
# std       0.224842     0.928929     1.472104     0.737154     0.579181  ...
# min       1.000000     1.000000     1.000000     1.000000     1.000000  ...
# 25%       2.000000     1.000000     3.000000     1.000000     1.000000  ...
# 50%       2.000000     2.000000     4.000000     1.000000     1.000000  ...
# 75%       2.000000     3.000000     5.000000     1.000000     2.000000  ...
# max       2.000000     7.000000    13.000000     6.000000     3.000000  ...
#
#            tot_hom      tot_muj      tot_hog     ubica_geo      tam_loc  \
# count  3524.000000  3524.000000  3524.000000   3524.000000  3524.000000
# mean      1.743473     1.912883     1.013905  15066.656640     2.638479
# std       1.175019     1.238544     0.130849     38.915093     1.364925
# min       0.000000     0.000000     1.000000  15001.000000     1.000000
# 25%       1.000000     1.000000     1.000000  15033.000000     1.000000
# 50%       2.000000     2.000000     1.000000  15063.000000     3.000000
# 75%       2.000000     3.000000     1.000000  15106.000000     4.000000
# max       9.000000     9.000000     4.000000  15124.000000     4.000000
#
#          est_socio      est_dis          upm       factor  procaptar
# count  3524.000000  3524.000000  3524.000000  3524.000000     3524.0
# mean      2.072077   298.912316  5282.848184  1430.040295        0.0
# std       0.853387     6.889582   132.603644  1190.292132        0.0
# min       1.000000   287.000000  5018.000000   190.000000        0.0
# 25%       1.000000   292.000000  5168.000000   362.000000        0.0
# 50%       2.000000   302.000000  5327.000000  1509.000000        0.0
# 75%       2.000000   306.000000  5400.000000  2141.250000        0.0
# max       4.000000   312.000000  5440.000000  7127.000000        0.0
#
# [8 rows x 69 columns]
# -- Top 15 correlaciones mas fuertes --
#       var1       var2  correlacion  abs_corr
# num_dueno1 num_dueno2    -1.000000  1.000000
#  tot_resid    tot_muj     0.804696  0.804696
#  tot_resid    tot_hom     0.779996  0.779996
# cuart_dorm num_cuarto     0.699046  0.699046
#   excusado    drenaje     0.683710  0.683710
# sanit_agua   regadera     0.657761  0.657761
# p_electric p_tuberias     0.654752  0.654752
# p_fractura p_electric     0.614857  0.614857
#   agua_ent sanit_agua     0.587097  0.587097
# aire_acond   calefacc     0.571199  0.571199
#   regadera tinaco_azo     0.564020  0.564020
# sanit_agua    drenaje     0.556793  0.556793
#   regadera calent_gas     0.551241  0.551241
#   cisterna bomba_agua     0.549843  0.549843
#   agua_ent   regadera     0.545091  0.545091
# -- Correlacion de atributos vs etiqueta (tenencia) --
# tam_loc       0.225231
# num_cuarto    0.202398
# calent_sol   -0.162991
# p_fractura   -0.060031
# regadera      0.023391
#          folioviv tipo_viv  mat_pared  mat_techos mat_pisos antiguedad  \
# 41814  1505018801        1          1          10         2         13
# 41815  1505018803        1          8          10         3         28
# 41816  1505018804        1          8          10         3         13
# 41817  1505019801        1          8          10         2         11
# 41818  1505019802        1          8           4         3         24
#
#        antigua_ne  cocina  cocina_dor  cuart_dorm  ...  tot_muj  tot_hog  \
# 41814         NaN       1         2.0           2  ...        2        1
# 41815         NaN       1         2.0           2  ...        1        1
# 41816         NaN       1         2.0           2  ...        1        1
# 41817         NaN       1         2.0           1  ...        1        1
# 41818         NaN       1         2.0           1  ...        0        1
#
#        ubica_geo  tam_loc  est_socio  est_dis   upm  factor  procaptar  \
# 41814      15002        3          2      287  5018    4340          0
# 41815      15002        3          2      287  5018    4340          0
# 41816      15002        3          2      287  5018    4340          0
# 41817      15002        1          1      288  5019    1286          0
# 41818      15002        1          1      288  5019    1286          0
#
#        cve_estado
# 41814          15
# 41815          15
# 41816          15
# 41817          15
# 41818          15
#
# [5 rows x 83 columns]
